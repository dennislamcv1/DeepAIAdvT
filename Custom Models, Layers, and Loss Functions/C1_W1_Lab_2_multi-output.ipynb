# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 209.2668 - y1_output_loss: 107.6836 - y2_output_loss: 100.9667 - y1_output_root_mean_squared_error: 10.3836 - y2_output_root_mean_squared_error: 10.0721 - val_loss: 209.4358 - val_y1_output_loss: 36.2802 - val_y2_output_loss: 166.2178 - val_y1_output_root_mean_squared_error: 6.1312 - val_y2_output_root_mean_squared_error: 13.1089
# Epoch 2/500
# 614/614 [==============================] - 0s 162us/sample - loss: 48.3268 - y1_output_loss: 14.6166 - y2_output_loss: 33.5810 - y1_output_root_mean_squared_error: 3.8289 - y2_output_root_mean_squared_error: 5.8023 - val_loss: 43.7553 - val_y1_output_loss: 13.3819 - val_y2_output_loss: 33.5508 - val_y1_output_root_mean_squared_error: 3.6196 - val_y2_output_root_mean_squared_error: 5.5366
# Epoch 3/500
# 614/614 [==============================] - 0s 150us/sample - loss: 22.9868 - y1_output_loss: 9.6715 - y2_output_loss: 13.2568 - y1_output_root_mean_squared_error: 3.1114 - y2_output_root_mean_squared_error: 3.6477 - val_loss: 43.0557 - val_y1_output_loss: 12.8922 - val_y2_output_loss: 33.7383 - val_y1_output_root_mean_squared_error: 3.5379 - val_y2_output_root_mean_squared_error: 5.5262
# Epoch 4/500
# 614/614 [==============================] - 0s 144us/sample - loss: 22.6017 - y1_output_loss: 8.8125 - y2_output_loss: 13.6526 - y1_output_root_mean_squared_error: 2.9770 - y2_output_root_mean_squared_error: 3.7066 - val_loss: 34.0252 - val_y1_output_loss: 11.8475 - val_y2_output_loss: 24.9225 - val_y1_output_root_mean_squared_error: 3.4152 - val_y2_output_root_mean_squared_error: 4.7288
# Epoch 5/500
# 614/614 [==============================] - 0s 160us/sample - loss: 21.8505 - y1_output_loss: 8.6848 - y2_output_loss: 13.0180 - y1_output_root_mean_squared_error: 2.9582 - y2_output_root_mean_squared_error: 3.6194 - val_loss: 23.1713 - val_y1_output_loss: 9.4827 - val_y2_output_loss: 15.4627 - val_y1_output_root_mean_squared_error: 3.0563 - val_y2_output_root_mean_squared_error: 3.7189
# Epoch 6/500
# 614/614 [==============================] - 0s 146us/sample - loss: 21.8537 - y1_output_loss: 8.4416 - y2_output_loss: 13.3441 - y1_output_root_mean_squared_error: 2.9057 - y2_output_root_mean_squared_error: 3.6621 - val_loss: 22.6996 - val_y1_output_loss: 9.2898 - val_y2_output_loss: 14.7414 - val_y1_output_root_mean_squared_error: 3.0312 - val_y2_output_root_mean_squared_error: 3.6758
# Epoch 7/500
# 614/614 [==============================] - 0s 147us/sample - loss: 20.3435 - y1_output_loss: 7.8456 - y2_output_loss: 12.3434 - y1_output_root_mean_squared_error: 2.8125 - y2_output_root_mean_squared_error: 3.5261 - val_loss: 22.6112 - val_y1_output_loss: 9.1868 - val_y2_output_loss: 14.7375 - val_y1_output_root_mean_squared_error: 3.0230 - val_y2_output_root_mean_squared_error: 3.6705
# Epoch 8/500
# 614/614 [==============================] - 0s 147us/sample - loss: 18.0624 - y1_output_loss: 7.7681 - y2_output_loss: 10.2949 - y1_output_root_mean_squared_error: 2.7765 - y2_output_root_mean_squared_error: 3.2177 - val_loss: 26.5773 - val_y1_output_loss: 10.5194 - val_y2_output_loss: 16.6894 - val_y1_output_root_mean_squared_error: 3.2721 - val_y2_output_root_mean_squared_error: 3.9838
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 18.0354 - y1_output_loss: 7.5282 - y2_output_loss: 10.6642 - y1_output_root_mean_squared_error: 2.7323 - y2_output_root_mean_squared_error: 3.2511 - val_loss: 30.7634 - val_y1_output_loss: 9.7938 - val_y2_output_loss: 20.5532 - val_y1_output_root_mean_squared_error: 3.1770 - val_y2_output_root_mean_squared_error: 4.5464
# Epoch 10/500
# 614/614 [==============================] - 0s 144us/sample - loss: 23.6515 - y1_output_loss: 8.6018 - y2_output_loss: 15.2750 - y1_output_root_mean_squared_error: 2.9265 - y2_output_root_mean_squared_error: 3.8842 - val_loss: 72.0362 - val_y1_output_loss: 17.9936 - val_y2_output_loss: 53.7686 - val_y1_output_root_mean_squared_error: 4.2493 - val_y2_output_root_mean_squared_error: 7.3471
# Epoch 11/500
# 614/614 [==============================] - 0s 150us/sample - loss: 17.3283 - y1_output_loss: 6.9741 - y2_output_loss: 10.3320 - y1_output_root_mean_squared_error: 2.6373 - y2_output_root_mean_squared_error: 3.2207 - val_loss: 30.7391 - val_y1_output_loss: 10.7600 - val_y2_output_loss: 22.6512 - val_y1_output_root_mean_squared_error: 3.2350 - val_y2_output_root_mean_squared_error: 4.5027
# Epoch 12/500
# 614/614 [==============================] - 0s 162us/sample - loss: 17.6541 - y1_output_loss: 6.9088 - y2_output_loss: 10.9661 - y1_output_root_mean_squared_error: 2.6210 - y2_output_root_mean_squared_error: 3.2839 - val_loss: 29.5498 - val_y1_output_loss: 10.0606 - val_y2_output_loss: 21.2014 - val_y1_output_root_mean_squared_error: 3.1680 - val_y2_output_root_mean_squared_error: 4.4174
# Epoch 13/500
# 614/614 [==============================] - 0s 149us/sample - loss: 16.8555 - y1_output_loss: 6.7974 - y2_output_loss: 10.3111 - y1_output_root_mean_squared_error: 2.5899 - y2_output_root_mean_squared_error: 3.1856 - val_loss: 21.4134 - val_y1_output_loss: 7.7374 - val_y2_output_loss: 14.4620 - val_y1_output_root_mean_squared_error: 2.7859 - val_y2_output_root_mean_squared_error: 3.6949
# Epoch 14/500
# 614/614 [==============================] - 0s 142us/sample - loss: 18.6246 - y1_output_loss: 7.0479 - y2_output_loss: 11.6740 - y1_output_root_mean_squared_error: 2.6424 - y2_output_root_mean_squared_error: 3.4121 - val_loss: 27.4828 - val_y1_output_loss: 8.8030 - val_y2_output_loss: 21.6841 - val_y1_output_root_mean_squared_error: 2.8971 - val_y2_output_root_mean_squared_error: 4.3692
# Epoch 15/500
# 614/614 [==============================] - 0s 145us/sample - loss: 16.4988 - y1_output_loss: 6.5263 - y2_output_loss: 9.9331 - y1_output_root_mean_squared_error: 2.5451 - y2_output_root_mean_squared_error: 3.1656 - val_loss: 21.7331 - val_y1_output_loss: 9.1397 - val_y2_output_loss: 12.8561 - val_y1_output_root_mean_squared_error: 3.0716 - val_y2_output_root_mean_squared_error: 3.5069
# Epoch 16/500
# 614/614 [==============================] - 0s 142us/sample - loss: 14.7794 - y1_output_loss: 5.8670 - y2_output_loss: 9.2910 - y1_output_root_mean_squared_error: 2.4017 - y2_output_root_mean_squared_error: 3.0019 - val_loss: 23.5295 - val_y1_output_loss: 8.6304 - val_y2_output_loss: 15.7017 - val_y1_output_root_mean_squared_error: 2.9645 - val_y2_output_root_mean_squared_error: 3.8394
# Epoch 17/500
# 614/614 [==============================] - 0s 135us/sample - loss: 15.0516 - y1_output_loss: 5.8088 - y2_output_loss: 9.2190 - y1_output_root_mean_squared_error: 2.4120 - y2_output_root_mean_squared_error: 3.0387 - val_loss: 17.1335 - val_y1_output_loss: 6.6925 - val_y2_output_loss: 11.7681 - val_y1_output_root_mean_squared_error: 2.5576 - val_y2_output_root_mean_squared_error: 3.2545
# Epoch 18/500
# 614/614 [==============================] - 0s 137us/sample - loss: 19.9359 - y1_output_loss: 7.2028 - y2_output_loss: 12.5900 - y1_output_root_mean_squared_error: 2.6958 - y2_output_root_mean_squared_error: 3.5593 - val_loss: 18.2521 - val_y1_output_loss: 6.7067 - val_y2_output_loss: 12.5576 - val_y1_output_root_mean_squared_error: 2.6117 - val_y2_output_root_mean_squared_error: 3.3810
# Epoch 19/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.6674 - y1_output_loss: 5.2035 - y2_output_loss: 8.3506 - y1_output_root_mean_squared_error: 2.2911 - y2_output_root_mean_squared_error: 2.9014 - val_loss: 17.3226 - val_y1_output_loss: 6.7648 - val_y2_output_loss: 10.8838 - val_y1_output_root_mean_squared_error: 2.6379 - val_y2_output_root_mean_squared_error: 3.2193
# Epoch 20/500
# 614/614 [==============================] - 0s 153us/sample - loss: 15.0296 - y1_output_loss: 5.3580 - y2_output_loss: 9.5836 - y1_output_root_mean_squared_error: 2.3221 - y2_output_root_mean_squared_error: 3.1044 - val_loss: 27.1030 - val_y1_output_loss: 7.6941 - val_y2_output_loss: 19.0230 - val_y1_output_root_mean_squared_error: 2.8136 - val_y2_output_root_mean_squared_error: 4.3803
# Epoch 21/500
# 614/614 [==============================] - 0s 142us/sample - loss: 12.6206 - y1_output_loss: 4.9703 - y2_output_loss: 7.5497 - y1_output_root_mean_squared_error: 2.2394 - y2_output_root_mean_squared_error: 2.7579 - val_loss: 16.3331 - val_y1_output_loss: 6.3847 - val_y2_output_loss: 10.4243 - val_y1_output_root_mean_squared_error: 2.5552 - val_y2_output_root_mean_squared_error: 3.1312
# Epoch 22/500
# 614/614 [==============================] - 0s 144us/sample - loss: 13.1434 - y1_output_loss: 4.8185 - y2_output_loss: 8.2708 - y1_output_root_mean_squared_error: 2.1951 - y2_output_root_mean_squared_error: 2.8853 - val_loss: 15.6888 - val_y1_output_loss: 5.5597 - val_y2_output_loss: 11.2422 - val_y1_output_root_mean_squared_error: 2.3737 - val_y2_output_root_mean_squared_error: 3.1709
# Epoch 23/500
# 614/614 [==============================] - 0s 148us/sample - loss: 11.9054 - y1_output_loss: 4.6074 - y2_output_loss: 7.2132 - y1_output_root_mean_squared_error: 2.1539 - y2_output_root_mean_squared_error: 2.6956 - val_loss: 14.7620 - val_y1_output_loss: 5.5955 - val_y2_output_loss: 9.7183 - val_y1_output_root_mean_squared_error: 2.3872 - val_y2_output_root_mean_squared_error: 3.0105
# Epoch 24/500
# 614/614 [==============================] - 0s 143us/sample - loss: 12.6761 - y1_output_loss: 4.9110 - y2_output_loss: 7.6919 - y1_output_root_mean_squared_error: 2.2207 - y2_output_root_mean_squared_error: 2.7829 - val_loss: 12.8847 - val_y1_output_loss: 4.9305 - val_y2_output_loss: 8.4400 - val_y1_output_root_mean_squared_error: 2.2428 - val_y2_output_root_mean_squared_error: 2.8026
# Epoch 25/500
# 614/614 [==============================] - 0s 150us/sample - loss: 12.1386 - y1_output_loss: 4.4225 - y2_output_loss: 7.7756 - y1_output_root_mean_squared_error: 2.1106 - y2_output_root_mean_squared_error: 2.7720 - val_loss: 29.1657 - val_y1_output_loss: 7.1556 - val_y2_output_loss: 21.4149 - val_y1_output_root_mean_squared_error: 2.7176 - val_y2_output_root_mean_squared_error: 4.6669
# Epoch 26/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.1088 - y1_output_loss: 4.0671 - y2_output_loss: 7.9676 - y1_output_root_mean_squared_error: 2.0249 - y2_output_root_mean_squared_error: 2.8299 - val_loss: 15.0189 - val_y1_output_loss: 5.1011 - val_y2_output_loss: 9.9057 - val_y1_output_root_mean_squared_error: 2.2961 - val_y2_output_root_mean_squared_error: 3.1220
# Epoch 27/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.0209 - y1_output_loss: 3.8184 - y2_output_loss: 6.2890 - y1_output_root_mean_squared_error: 1.9318 - y2_output_root_mean_squared_error: 2.5078 - val_loss: 25.4838 - val_y1_output_loss: 10.7695 - val_y2_output_loss: 14.2600 - val_y1_output_root_mean_squared_error: 3.3232 - val_y2_output_root_mean_squared_error: 3.8000
# Epoch 28/500
# 614/614 [==============================] - 0s 145us/sample - loss: 12.1984 - y1_output_loss: 4.1889 - y2_output_loss: 7.9030 - y1_output_root_mean_squared_error: 2.0560 - y2_output_root_mean_squared_error: 2.8233 - val_loss: 13.1324 - val_y1_output_loss: 4.8509 - val_y2_output_loss: 8.8100 - val_y1_output_root_mean_squared_error: 2.2305 - val_y2_output_root_mean_squared_error: 2.8561
# Epoch 29/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.3805 - y1_output_loss: 3.8632 - y2_output_loss: 6.5528 - y1_output_root_mean_squared_error: 1.9511 - y2_output_root_mean_squared_error: 2.5639 - val_loss: 14.3504 - val_y1_output_loss: 5.8741 - val_y2_output_loss: 9.7854 - val_y1_output_root_mean_squared_error: 2.3711 - val_y2_output_root_mean_squared_error: 2.9543
# Epoch 30/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.3586 - y1_output_loss: 3.5133 - y2_output_loss: 5.8204 - y1_output_root_mean_squared_error: 1.8797 - y2_output_root_mean_squared_error: 2.4136 - val_loss: 28.1065 - val_y1_output_loss: 6.5550 - val_y2_output_loss: 20.9955 - val_y1_output_root_mean_squared_error: 2.6011 - val_y2_output_root_mean_squared_error: 4.6196
# Epoch 31/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.9282 - y1_output_loss: 4.1359 - y2_output_loss: 6.9906 - y1_output_root_mean_squared_error: 1.9997 - y2_output_root_mean_squared_error: 2.6324 - val_loss: 38.9891 - val_y1_output_loss: 12.1672 - val_y2_output_loss: 30.0165 - val_y1_output_root_mean_squared_error: 3.3921 - val_y2_output_root_mean_squared_error: 5.2424
# Epoch 32/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.8886 - y1_output_loss: 3.7794 - y2_output_loss: 7.0846 - y1_output_root_mean_squared_error: 1.9492 - y2_output_root_mean_squared_error: 2.6625 - val_loss: 10.8608 - val_y1_output_loss: 3.7153 - val_y2_output_loss: 7.4237 - val_y1_output_root_mean_squared_error: 1.9530 - val_y2_output_root_mean_squared_error: 2.6545
# Epoch 33/500
# 614/614 [==============================] - 0s 149us/sample - loss: 9.0787 - y1_output_loss: 3.1552 - y2_output_loss: 5.9279 - y1_output_root_mean_squared_error: 1.7810 - y2_output_root_mean_squared_error: 2.4304 - val_loss: 11.1940 - val_y1_output_loss: 4.1817 - val_y2_output_loss: 7.3019 - val_y1_output_root_mean_squared_error: 2.0777 - val_y2_output_root_mean_squared_error: 2.6224
# Epoch 34/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.2323 - y1_output_loss: 3.5603 - y2_output_loss: 6.6842 - y1_output_root_mean_squared_error: 1.8740 - y2_output_root_mean_squared_error: 2.5924 - val_loss: 15.0466 - val_y1_output_loss: 4.2419 - val_y2_output_loss: 11.8589 - val_y1_output_root_mean_squared_error: 2.0593 - val_y2_output_root_mean_squared_error: 3.2872
# Epoch 35/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.2802 - y1_output_loss: 3.2903 - y2_output_loss: 5.9714 - y1_output_root_mean_squared_error: 1.8077 - y2_output_root_mean_squared_error: 2.4520 - val_loss: 12.9188 - val_y1_output_loss: 4.4109 - val_y2_output_loss: 8.4339 - val_y1_output_root_mean_squared_error: 2.1403 - val_y2_output_root_mean_squared_error: 2.8875
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.4614 - y1_output_loss: 3.2537 - y2_output_loss: 6.2195 - y1_output_root_mean_squared_error: 1.8057 - y2_output_root_mean_squared_error: 2.4902 - val_loss: 28.1379 - val_y1_output_loss: 8.8253 - val_y2_output_loss: 18.4558 - val_y1_output_root_mean_squared_error: 3.0149 - val_y2_output_root_mean_squared_error: 4.3644
# Epoch 37/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.0865 - y1_output_loss: 3.1556 - y2_output_loss: 5.8969 - y1_output_root_mean_squared_error: 1.7792 - y2_output_root_mean_squared_error: 2.4333 - val_loss: 15.9138 - val_y1_output_loss: 4.5144 - val_y2_output_loss: 12.4721 - val_y1_output_root_mean_squared_error: 2.1091 - val_y2_output_root_mean_squared_error: 3.3861
# Epoch 38/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.7860 - y1_output_loss: 3.0722 - y2_output_loss: 6.7502 - y1_output_root_mean_squared_error: 1.7560 - y2_output_root_mean_squared_error: 2.5889 - val_loss: 24.6915 - val_y1_output_loss: 8.0571 - val_y2_output_loss: 16.0459 - val_y1_output_root_mean_squared_error: 2.8868 - val_y2_output_root_mean_squared_error: 4.0445
# Epoch 39/500
# 614/614 [==============================] - 0s 148us/sample - loss: 9.9288 - y1_output_loss: 3.3834 - y2_output_loss: 6.7053 - y1_output_root_mean_squared_error: 1.8219 - y2_output_root_mean_squared_error: 2.5709 - val_loss: 40.4160 - val_y1_output_loss: 9.0554 - val_y2_output_loss: 30.1796 - val_y1_output_root_mean_squared_error: 3.0646 - val_y2_output_root_mean_squared_error: 5.5699
# Epoch 40/500
# 614/614 [==============================] - 0s 141us/sample - loss: 10.9681 - y1_output_loss: 3.7016 - y2_output_loss: 7.2449 - y1_output_root_mean_squared_error: 1.9269 - y2_output_root_mean_squared_error: 2.6935 - val_loss: 19.8088 - val_y1_output_loss: 5.3986 - val_y2_output_loss: 13.9434 - val_y1_output_root_mean_squared_error: 2.3606 - val_y2_output_root_mean_squared_error: 3.7731
# Epoch 41/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.4089 - y1_output_loss: 2.8777 - y2_output_loss: 6.4627 - y1_output_root_mean_squared_error: 1.7044 - y2_output_root_mean_squared_error: 2.5503 - val_loss: 9.4611 - val_y1_output_loss: 2.9528 - val_y2_output_loss: 7.0021 - val_y1_output_root_mean_squared_error: 1.7441 - val_y2_output_root_mean_squared_error: 2.5336
# Epoch 42/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.7148 - y1_output_loss: 2.3445 - y2_output_loss: 4.3118 - y1_output_root_mean_squared_error: 1.5370 - y2_output_root_mean_squared_error: 2.0863 - val_loss: 9.6678 - val_y1_output_loss: 3.1779 - val_y2_output_loss: 6.4451 - val_y1_output_root_mean_squared_error: 1.8116 - val_y2_output_root_mean_squared_error: 2.5270
# Epoch 43/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.1363 - y1_output_loss: 2.6495 - y2_output_loss: 5.4953 - y1_output_root_mean_squared_error: 1.6293 - y2_output_root_mean_squared_error: 2.3413 - val_loss: 17.7589 - val_y1_output_loss: 5.0481 - val_y2_output_loss: 13.8940 - val_y1_output_root_mean_squared_error: 2.2272 - val_y2_output_root_mean_squared_error: 3.5775
# Epoch 44/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.2951 - y1_output_loss: 2.4122 - y2_output_loss: 4.8540 - y1_output_root_mean_squared_error: 1.5499 - y2_output_root_mean_squared_error: 2.2120 - val_loss: 7.7929 - val_y1_output_loss: 2.3163 - val_y2_output_loss: 5.8689 - val_y1_output_root_mean_squared_error: 1.5369 - val_y2_output_root_mean_squared_error: 2.3304
# Epoch 45/500
# 614/614 [==============================] - 0s 166us/sample - loss: 7.9669 - y1_output_loss: 2.4769 - y2_output_loss: 5.4309 - y1_output_root_mean_squared_error: 1.5786 - y2_output_root_mean_squared_error: 2.3399 - val_loss: 7.1141 - val_y1_output_loss: 2.2843 - val_y2_output_loss: 5.1068 - val_y1_output_root_mean_squared_error: 1.5291 - val_y2_output_root_mean_squared_error: 2.1854
# Epoch 46/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.7045 - y1_output_loss: 2.0592 - y2_output_loss: 4.6010 - y1_output_root_mean_squared_error: 1.4393 - y2_output_root_mean_squared_error: 2.1524 - val_loss: 9.9597 - val_y1_output_loss: 2.7464 - val_y2_output_loss: 7.1426 - val_y1_output_root_mean_squared_error: 1.6850 - val_y2_output_root_mean_squared_error: 2.6684
# Epoch 47/500
# 614/614 [==============================] - 0s 152us/sample - loss: 9.0975 - y1_output_loss: 2.9056 - y2_output_loss: 6.2258 - y1_output_root_mean_squared_error: 1.6996 - y2_output_root_mean_squared_error: 2.4918 - val_loss: 8.6694 - val_y1_output_loss: 2.6983 - val_y2_output_loss: 6.1696 - val_y1_output_root_mean_squared_error: 1.6677 - val_y2_output_root_mean_squared_error: 2.4266
# Epoch 48/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.7301 - y1_output_loss: 2.0820 - y2_output_loss: 3.7257 - y1_output_root_mean_squared_error: 1.4284 - y2_output_root_mean_squared_error: 1.9209 - val_loss: 13.7146 - val_y1_output_loss: 3.7609 - val_y2_output_loss: 10.8133 - val_y1_output_root_mean_squared_error: 1.9367 - val_y2_output_root_mean_squared_error: 3.1566
# Epoch 49/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.4533 - y1_output_loss: 2.2732 - y2_output_loss: 5.1589 - y1_output_root_mean_squared_error: 1.4998 - y2_output_root_mean_squared_error: 2.2812 - val_loss: 8.7158 - val_y1_output_loss: 2.8054 - val_y2_output_loss: 6.2599 - val_y1_output_root_mean_squared_error: 1.7055 - val_y2_output_root_mean_squared_error: 2.4098
# Epoch 50/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.6615 - y1_output_loss: 2.2409 - y2_output_loss: 4.4145 - y1_output_root_mean_squared_error: 1.4924 - y2_output_root_mean_squared_error: 2.1058 - val_loss: 7.1506 - val_y1_output_loss: 1.9905 - val_y2_output_loss: 5.6872 - val_y1_output_root_mean_squared_error: 1.4264 - val_y2_output_root_mean_squared_error: 2.2618
# Epoch 51/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.5385 - y1_output_loss: 2.2114 - y2_output_loss: 5.3119 - y1_output_root_mean_squared_error: 1.4932 - y2_output_root_mean_squared_error: 2.3041 - val_loss: 8.8957 - val_y1_output_loss: 2.2233 - val_y2_output_loss: 6.7604 - val_y1_output_root_mean_squared_error: 1.5009 - val_y2_output_root_mean_squared_error: 2.5774
# Epoch 52/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.2907 - y1_output_loss: 2.0265 - y2_output_loss: 4.2954 - y1_output_root_mean_squared_error: 1.4267 - y2_output_root_mean_squared_error: 2.0628 - val_loss: 7.0489 - val_y1_output_loss: 2.3028 - val_y2_output_loss: 5.0619 - val_y1_output_root_mean_squared_error: 1.5299 - val_y2_output_root_mean_squared_error: 2.1699
# Epoch 53/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.0644 - y1_output_loss: 1.8978 - y2_output_loss: 4.2271 - y1_output_root_mean_squared_error: 1.3766 - y2_output_root_mean_squared_error: 2.0419 - val_loss: 13.5692 - val_y1_output_loss: 4.2788 - val_y2_output_loss: 9.9519 - val_y1_output_root_mean_squared_error: 2.0608 - val_y2_output_root_mean_squared_error: 3.0533
# Epoch 54/500
# 614/614 [==============================] - 0s 160us/sample - loss: 7.6089 - y1_output_loss: 2.3378 - y2_output_loss: 5.2463 - y1_output_root_mean_squared_error: 1.5264 - y2_output_root_mean_squared_error: 2.2976 - val_loss: 16.3112 - val_y1_output_loss: 4.9941 - val_y2_output_loss: 11.0049 - val_y1_output_root_mean_squared_error: 2.2750 - val_y2_output_root_mean_squared_error: 3.3370
# Epoch 55/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.1453 - y1_output_loss: 2.4689 - y2_output_loss: 5.7421 - y1_output_root_mean_squared_error: 1.5773 - y2_output_root_mean_squared_error: 2.3785 - val_loss: 10.6353 - val_y1_output_loss: 2.0463 - val_y2_output_loss: 8.4528 - val_y1_output_root_mean_squared_error: 1.4556 - val_y2_output_root_mean_squared_error: 2.9183
# Epoch 56/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.7085 - y1_output_loss: 2.1274 - y2_output_loss: 4.5306 - y1_output_root_mean_squared_error: 1.4656 - y2_output_root_mean_squared_error: 2.1356 - val_loss: 6.9366 - val_y1_output_loss: 2.2149 - val_y2_output_loss: 5.1892 - val_y1_output_root_mean_squared_error: 1.5073 - val_y2_output_root_mean_squared_error: 2.1598
# Epoch 57/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.4092 - y1_output_loss: 2.2843 - y2_output_loss: 5.1099 - y1_output_root_mean_squared_error: 1.5127 - y2_output_root_mean_squared_error: 2.2629 - val_loss: 11.9533 - val_y1_output_loss: 4.5983 - val_y2_output_loss: 7.5749 - val_y1_output_root_mean_squared_error: 2.1371 - val_y2_output_root_mean_squared_error: 2.7177
# Epoch 58/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.9336 - y1_output_loss: 2.0047 - y2_output_loss: 3.8894 - y1_output_root_mean_squared_error: 1.4195 - y2_output_root_mean_squared_error: 1.9796 - val_loss: 7.8907 - val_y1_output_loss: 2.4164 - val_y2_output_loss: 5.9365 - val_y1_output_root_mean_squared_error: 1.5665 - val_y2_output_root_mean_squared_error: 2.3317
# Epoch 59/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.6052 - y1_output_loss: 2.9827 - y2_output_loss: 7.6409 - y1_output_root_mean_squared_error: 1.7180 - y2_output_root_mean_squared_error: 2.7665 - val_loss: 16.4392 - val_y1_output_loss: 5.0301 - val_y2_output_loss: 12.2328 - val_y1_output_root_mean_squared_error: 2.2362 - val_y2_output_root_mean_squared_error: 3.3821
# Epoch 60/500
# 614/614 [==============================] - 0s 152us/sample - loss: 7.3693 - y1_output_loss: 2.1289 - y2_output_loss: 5.2388 - y1_output_root_mean_squared_error: 1.4519 - y2_output_root_mean_squared_error: 2.2937 - val_loss: 9.4427 - val_y1_output_loss: 2.5894 - val_y2_output_loss: 7.2262 - val_y1_output_root_mean_squared_error: 1.6276 - val_y2_output_root_mean_squared_error: 2.6064
# Epoch 61/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.5271 - y1_output_loss: 1.7679 - y2_output_loss: 3.8041 - y1_output_root_mean_squared_error: 1.3136 - y2_output_root_mean_squared_error: 1.9498 - val_loss: 17.0138 - val_y1_output_loss: 4.6219 - val_y2_output_loss: 13.2224 - val_y1_output_root_mean_squared_error: 2.1544 - val_y2_output_root_mean_squared_error: 3.5174
# Epoch 62/500
# 614/614 [==============================] - 0s 150us/sample - loss: 6.8700 - y1_output_loss: 2.0149 - y2_output_loss: 4.9130 - y1_output_root_mean_squared_error: 1.4202 - y2_output_root_mean_squared_error: 2.2029 - val_loss: 39.2946 - val_y1_output_loss: 9.3060 - val_y2_output_loss: 29.0283 - val_y1_output_root_mean_squared_error: 3.0856 - val_y2_output_root_mean_squared_error: 5.4565
# Epoch 63/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.6620 - y1_output_loss: 2.0469 - y2_output_loss: 4.6113 - y1_output_root_mean_squared_error: 1.4267 - y2_output_root_mean_squared_error: 2.1510 - val_loss: 7.1066 - val_y1_output_loss: 1.9257 - val_y2_output_loss: 5.2465 - val_y1_output_root_mean_squared_error: 1.4008 - val_y2_output_root_mean_squared_error: 2.2681
# Epoch 64/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.6706 - y1_output_loss: 2.2150 - y2_output_loss: 5.5109 - y1_output_root_mean_squared_error: 1.4896 - y2_output_root_mean_squared_error: 2.3349 - val_loss: 14.6691 - val_y1_output_loss: 4.4225 - val_y2_output_loss: 10.3200 - val_y1_output_root_mean_squared_error: 2.1155 - val_y2_output_root_mean_squared_error: 3.1928
# Epoch 65/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.8426 - y1_output_loss: 1.8648 - y2_output_loss: 3.9676 - y1_output_root_mean_squared_error: 1.3665 - y2_output_root_mean_squared_error: 1.9938 - val_loss: 6.4852 - val_y1_output_loss: 1.9684 - val_y2_output_loss: 4.7327 - val_y1_output_root_mean_squared_error: 1.4231 - val_y2_output_root_mean_squared_error: 2.1118
# Epoch 66/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.1115 - y1_output_loss: 1.5511 - y2_output_loss: 3.5418 - y1_output_root_mean_squared_error: 1.2487 - y2_output_root_mean_squared_error: 1.8848 - val_loss: 6.7886 - val_y1_output_loss: 1.9936 - val_y2_output_loss: 5.2058 - val_y1_output_root_mean_squared_error: 1.4269 - val_y2_output_root_mean_squared_error: 2.1800
# Epoch 67/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.4859 - y1_output_loss: 1.4143 - y2_output_loss: 4.0387 - y1_output_root_mean_squared_error: 1.1934 - y2_output_root_mean_squared_error: 2.0154 - val_loss: 5.7727 - val_y1_output_loss: 1.4314 - val_y2_output_loss: 4.5320 - val_y1_output_root_mean_squared_error: 1.2141 - val_y2_output_root_mean_squared_error: 2.0733
# Epoch 68/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.9574 - y1_output_loss: 1.3608 - y2_output_loss: 3.5533 - y1_output_root_mean_squared_error: 1.1713 - y2_output_root_mean_squared_error: 1.8936 - val_loss: 6.6487 - val_y1_output_loss: 2.1723 - val_y2_output_loss: 4.5312 - val_y1_output_root_mean_squared_error: 1.4853 - val_y2_output_root_mean_squared_error: 2.1077
# Epoch 69/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.8914 - y1_output_loss: 1.8319 - y2_output_loss: 5.0259 - y1_output_root_mean_squared_error: 1.3598 - y2_output_root_mean_squared_error: 2.2455 - val_loss: 9.4278 - val_y1_output_loss: 1.8105 - val_y2_output_loss: 7.5238 - val_y1_output_root_mean_squared_error: 1.3516 - val_y2_output_root_mean_squared_error: 2.7570
# Epoch 70/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.7935 - y1_output_loss: 1.4570 - y2_output_loss: 3.3071 - y1_output_root_mean_squared_error: 1.2098 - y2_output_root_mean_squared_error: 1.8248 - val_loss: 5.8735 - val_y1_output_loss: 1.6651 - val_y2_output_loss: 4.2995 - val_y1_output_root_mean_squared_error: 1.2969 - val_y2_output_root_mean_squared_error: 2.0473
# Epoch 71/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.8395 - y1_output_loss: 1.5945 - y2_output_loss: 4.1952 - y1_output_root_mean_squared_error: 1.2687 - y2_output_root_mean_squared_error: 2.0567 - val_loss: 4.8221 - val_y1_output_loss: 1.1415 - val_y2_output_loss: 4.0554 - val_y1_output_root_mean_squared_error: 1.0762 - val_y2_output_root_mean_squared_error: 1.9141
# Epoch 72/500
# 614/614 [==============================] - 0s 147us/sample - loss: 12.7019 - y1_output_loss: 4.0481 - y2_output_loss: 8.5357 - y1_output_root_mean_squared_error: 2.0211 - y2_output_root_mean_squared_error: 2.9355 - val_loss: 5.2784 - val_y1_output_loss: 1.3308 - val_y2_output_loss: 4.4266 - val_y1_output_root_mean_squared_error: 1.1566 - val_y2_output_root_mean_squared_error: 1.9851
# Epoch 73/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.7841 - y1_output_loss: 1.2690 - y2_output_loss: 3.4868 - y1_output_root_mean_squared_error: 1.1259 - y2_output_root_mean_squared_error: 1.8752 - val_loss: 5.6702 - val_y1_output_loss: 1.8280 - val_y2_output_loss: 4.0476 - val_y1_output_root_mean_squared_error: 1.3703 - val_y2_output_root_mean_squared_error: 1.9474
# Epoch 74/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.1843 - y1_output_loss: 1.1551 - y2_output_loss: 3.0038 - y1_output_root_mean_squared_error: 1.0745 - y2_output_root_mean_squared_error: 1.7406 - val_loss: 4.8098 - val_y1_output_loss: 1.1904 - val_y2_output_loss: 4.1073 - val_y1_output_root_mean_squared_error: 1.0880 - val_y2_output_root_mean_squared_error: 1.9042
# Epoch 75/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.5016 - y1_output_loss: 1.4664 - y2_output_loss: 4.0644 - y1_output_root_mean_squared_error: 1.2086 - y2_output_root_mean_squared_error: 2.0102 - val_loss: 4.9953 - val_y1_output_loss: 1.3284 - val_y2_output_loss: 3.9232 - val_y1_output_root_mean_squared_error: 1.1587 - val_y2_output_root_mean_squared_error: 1.9112
# Epoch 76/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.8819 - y1_output_loss: 1.0467 - y2_output_loss: 2.8460 - y1_output_root_mean_squared_error: 1.0214 - y2_output_root_mean_squared_error: 1.6848 - val_loss: 6.0484 - val_y1_output_loss: 1.2425 - val_y2_output_loss: 4.9962 - val_y1_output_root_mean_squared_error: 1.1354 - val_y2_output_root_mean_squared_error: 2.1816
# Epoch 77/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.4758 - y1_output_loss: 1.1506 - y2_output_loss: 3.3025 - y1_output_root_mean_squared_error: 1.0704 - y2_output_root_mean_squared_error: 1.8249 - val_loss: 5.5906 - val_y1_output_loss: 1.9165 - val_y2_output_loss: 4.1307 - val_y1_output_root_mean_squared_error: 1.3714 - val_y2_output_root_mean_squared_error: 1.9261
# Epoch 78/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.6016 - y1_output_loss: 1.2818 - y2_output_loss: 3.2908 - y1_output_root_mean_squared_error: 1.1333 - y2_output_root_mean_squared_error: 1.8213 - val_loss: 4.5772 - val_y1_output_loss: 1.0134 - val_y2_output_loss: 4.0726 - val_y1_output_root_mean_squared_error: 1.0180 - val_y2_output_root_mean_squared_error: 1.8817
# Epoch 79/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.0488 - y1_output_loss: 1.1180 - y2_output_loss: 2.9136 - y1_output_root_mean_squared_error: 1.0541 - y2_output_root_mean_squared_error: 1.7140 - val_loss: 4.7389 - val_y1_output_loss: 1.1380 - val_y2_output_loss: 4.1488 - val_y1_output_root_mean_squared_error: 1.0719 - val_y2_output_root_mean_squared_error: 1.8947
# Epoch 80/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.2419 - y1_output_loss: 1.1056 - y2_output_loss: 3.1071 - y1_output_root_mean_squared_error: 1.0529 - y2_output_root_mean_squared_error: 1.7701 - val_loss: 4.4230 - val_y1_output_loss: 1.1517 - val_y2_output_loss: 3.5054 - val_y1_output_root_mean_squared_error: 1.0782 - val_y2_output_root_mean_squared_error: 1.8057
# Epoch 81/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.4978 - y1_output_loss: 0.9242 - y2_output_loss: 2.5635 - y1_output_root_mean_squared_error: 0.9592 - y2_output_root_mean_squared_error: 1.6055 - val_loss: 4.3832 - val_y1_output_loss: 1.0915 - val_y2_output_loss: 3.6673 - val_y1_output_root_mean_squared_error: 1.0545 - val_y2_output_root_mean_squared_error: 1.8086
# Epoch 82/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.2807 - y1_output_loss: 1.1271 - y2_output_loss: 3.1381 - y1_output_root_mean_squared_error: 1.0559 - y2_output_root_mean_squared_error: 1.7792 - val_loss: 4.3195 - val_y1_output_loss: 0.9335 - val_y2_output_loss: 3.9526 - val_y1_output_root_mean_squared_error: 0.9601 - val_y2_output_root_mean_squared_error: 1.8433
# Epoch 83/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.4787 - y1_output_loss: 0.9251 - y2_output_loss: 2.5569 - y1_output_root_mean_squared_error: 0.9575 - y2_output_root_mean_squared_error: 1.6006 - val_loss: 6.3502 - val_y1_output_loss: 1.0748 - val_y2_output_loss: 6.0144 - val_y1_output_root_mean_squared_error: 1.0401 - val_y2_output_root_mean_squared_error: 2.2953
# Epoch 84/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.8719 - y1_output_loss: 1.7452 - y2_output_loss: 4.0863 - y1_output_root_mean_squared_error: 1.3265 - y2_output_root_mean_squared_error: 2.0279 - val_loss: 5.0252 - val_y1_output_loss: 0.9652 - val_y2_output_loss: 4.3505 - val_y1_output_root_mean_squared_error: 0.9919 - val_y2_output_root_mean_squared_error: 2.0103
# Epoch 85/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.8511 - y1_output_loss: 1.0152 - y2_output_loss: 2.8285 - y1_output_root_mean_squared_error: 1.0104 - y2_output_root_mean_squared_error: 1.6823 - val_loss: 6.1877 - val_y1_output_loss: 0.8616 - val_y2_output_loss: 5.4060 - val_y1_output_root_mean_squared_error: 0.9397 - val_y2_output_root_mean_squared_error: 2.3032
# Epoch 86/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.1031 - y1_output_loss: 0.6947 - y2_output_loss: 2.3854 - y1_output_root_mean_squared_error: 0.8352 - y2_output_root_mean_squared_error: 1.5510 - val_loss: 3.7651 - val_y1_output_loss: 0.8922 - val_y2_output_loss: 3.1662 - val_y1_output_root_mean_squared_error: 0.9578 - val_y2_output_root_mean_squared_error: 1.6875
# Epoch 87/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.3157 - y1_output_loss: 0.8173 - y2_output_loss: 2.4695 - y1_output_root_mean_squared_error: 0.9076 - y2_output_root_mean_squared_error: 1.5786 - val_loss: 3.9236 - val_y1_output_loss: 0.7183 - val_y2_output_loss: 3.7086 - val_y1_output_root_mean_squared_error: 0.8585 - val_y2_output_root_mean_squared_error: 1.7851
# Epoch 88/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.1769 - y1_output_loss: 0.8353 - y2_output_loss: 2.4006 - y1_output_root_mean_squared_error: 0.9137 - y2_output_root_mean_squared_error: 1.5304 - val_loss: 21.6798 - val_y1_output_loss: 2.9432 - val_y2_output_loss: 18.3528 - val_y1_output_root_mean_squared_error: 1.7279 - val_y2_output_root_mean_squared_error: 4.3237
# Epoch 89/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.8870 - y1_output_loss: 1.9716 - y2_output_loss: 4.8653 - y1_output_root_mean_squared_error: 1.4093 - y2_output_root_mean_squared_error: 2.2138 - val_loss: 6.7342 - val_y1_output_loss: 1.3584 - val_y2_output_loss: 6.1445 - val_y1_output_root_mean_squared_error: 1.1594 - val_y2_output_root_mean_squared_error: 2.3217
# Epoch 90/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.1725 - y1_output_loss: 0.7170 - y2_output_loss: 2.4710 - y1_output_root_mean_squared_error: 0.8434 - y2_output_root_mean_squared_error: 1.5688 - val_loss: 11.5776 - val_y1_output_loss: 3.5433 - val_y2_output_loss: 8.6811 - val_y1_output_root_mean_squared_error: 1.8918 - val_y2_output_root_mean_squared_error: 2.8282
# Epoch 91/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.2145 - y1_output_loss: 1.1369 - y2_output_loss: 3.0500 - y1_output_root_mean_squared_error: 1.0695 - y2_output_root_mean_squared_error: 1.7523 - val_loss: 3.3443 - val_y1_output_loss: 0.7259 - val_y2_output_loss: 2.8911 - val_y1_output_root_mean_squared_error: 0.8596 - val_y2_output_root_mean_squared_error: 1.6141
# Epoch 92/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.6528 - y1_output_loss: 0.5926 - y2_output_loss: 2.0505 - y1_output_root_mean_squared_error: 0.7705 - y2_output_root_mean_squared_error: 1.4350 - val_loss: 3.8706 - val_y1_output_loss: 0.8935 - val_y2_output_loss: 3.4418 - val_y1_output_root_mean_squared_error: 0.9456 - val_y2_output_root_mean_squared_error: 1.7252
# Epoch 93/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.5050 - y1_output_loss: 1.0989 - y2_output_loss: 3.4082 - y1_output_root_mean_squared_error: 1.0530 - y2_output_root_mean_squared_error: 1.8429 - val_loss: 6.8369 - val_y1_output_loss: 0.8356 - val_y2_output_loss: 5.9798 - val_y1_output_root_mean_squared_error: 0.9155 - val_y2_output_root_mean_squared_error: 2.4492
# Epoch 94/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.9954 - y1_output_loss: 0.6233 - y2_output_loss: 2.3450 - y1_output_root_mean_squared_error: 0.7927 - y2_output_root_mean_squared_error: 1.5385 - val_loss: 2.9787 - val_y1_output_loss: 0.5184 - val_y2_output_loss: 2.7592 - val_y1_output_root_mean_squared_error: 0.7274 - val_y2_output_root_mean_squared_error: 1.5651
# Epoch 95/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.0913 - y1_output_loss: 0.7072 - y2_output_loss: 2.4021 - y1_output_root_mean_squared_error: 0.8306 - y2_output_root_mean_squared_error: 1.5497 - val_loss: 3.7728 - val_y1_output_loss: 0.8056 - val_y2_output_loss: 3.4817 - val_y1_output_root_mean_squared_error: 0.8805 - val_y2_output_root_mean_squared_error: 1.7314
# Epoch 96/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.8988 - y1_output_loss: 0.5881 - y2_output_loss: 2.3292 - y1_output_root_mean_squared_error: 0.7614 - y2_output_root_mean_squared_error: 1.5228 - val_loss: 3.5294 - val_y1_output_loss: 0.8501 - val_y2_output_loss: 2.9774 - val_y1_output_root_mean_squared_error: 0.9289 - val_y2_output_root_mean_squared_error: 1.6330
# Epoch 97/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.0604 - y1_output_loss: 0.7400 - y2_output_loss: 2.3111 - y1_output_root_mean_squared_error: 0.8597 - y2_output_root_mean_squared_error: 1.5236 - val_loss: 4.2832 - val_y1_output_loss: 0.6461 - val_y2_output_loss: 4.1393 - val_y1_output_root_mean_squared_error: 0.8111 - val_y2_output_root_mean_squared_error: 1.9040
# Epoch 98/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.6365 - y1_output_loss: 0.9369 - y2_output_loss: 2.6752 - y1_output_root_mean_squared_error: 0.9693 - y2_output_root_mean_squared_error: 1.6422 - val_loss: 3.5392 - val_y1_output_loss: 0.8743 - val_y2_output_loss: 2.9180 - val_y1_output_root_mean_squared_error: 0.9337 - val_y2_output_root_mean_squared_error: 1.6332
# Epoch 99/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1017 - y1_output_loss: 0.7140 - y2_output_loss: 2.3770 - y1_output_root_mean_squared_error: 0.8469 - y2_output_root_mean_squared_error: 1.5442 - val_loss: 4.7002 - val_y1_output_loss: 0.7832 - val_y2_output_loss: 4.4457 - val_y1_output_root_mean_squared_error: 0.8935 - val_y2_output_root_mean_squared_error: 1.9753
# Epoch 100/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.6507 - y1_output_loss: 1.4843 - y2_output_loss: 4.1685 - y1_output_root_mean_squared_error: 1.2212 - y2_output_root_mean_squared_error: 2.0394 - val_loss: 5.8693 - val_y1_output_loss: 0.6802 - val_y2_output_loss: 5.8785 - val_y1_output_root_mean_squared_error: 0.8199 - val_y2_output_root_mean_squared_error: 2.2797
# Epoch 101/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.8631 - y1_output_loss: 0.6942 - y2_output_loss: 2.1453 - y1_output_root_mean_squared_error: 0.8358 - y2_output_root_mean_squared_error: 1.4712 - val_loss: 2.8951 - val_y1_output_loss: 0.5871 - val_y2_output_loss: 2.6281 - val_y1_output_root_mean_squared_error: 0.7763 - val_y2_output_root_mean_squared_error: 1.5141
# Epoch 102/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.0187 - y1_output_loss: 1.1604 - y2_output_loss: 2.8441 - y1_output_root_mean_squared_error: 1.0727 - y2_output_root_mean_squared_error: 1.6935 - val_loss: 3.1542 - val_y1_output_loss: 0.6880 - val_y2_output_loss: 2.7452 - val_y1_output_root_mean_squared_error: 0.8329 - val_y2_output_root_mean_squared_error: 1.5686
# Epoch 103/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.8598 - y1_output_loss: 1.1011 - y2_output_loss: 2.7535 - y1_output_root_mean_squared_error: 1.0491 - y2_output_root_mean_squared_error: 1.6611 - val_loss: 2.7883 - val_y1_output_loss: 0.6481 - val_y2_output_loss: 2.3750 - val_y1_output_root_mean_squared_error: 0.8075 - val_y2_output_root_mean_squared_error: 1.4616
# Epoch 104/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.9313 - y1_output_loss: 0.9778 - y2_output_loss: 2.9308 - y1_output_root_mean_squared_error: 0.9898 - y2_output_root_mean_squared_error: 1.7180 - val_loss: 2.9958 - val_y1_output_loss: 0.7602 - val_y2_output_loss: 2.4454 - val_y1_output_root_mean_squared_error: 0.8726 - val_y2_output_root_mean_squared_error: 1.4948
# Epoch 105/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.2447 - y1_output_loss: 0.5061 - y2_output_loss: 1.7457 - y1_output_root_mean_squared_error: 0.7096 - y2_output_root_mean_squared_error: 1.3195 - val_loss: 3.8816 - val_y1_output_loss: 0.8743 - val_y2_output_loss: 3.3875 - val_y1_output_root_mean_squared_error: 0.9434 - val_y2_output_root_mean_squared_error: 1.7296
# Epoch 106/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.5458 - y1_output_loss: 0.5744 - y2_output_loss: 1.9740 - y1_output_root_mean_squared_error: 0.7600 - y2_output_root_mean_squared_error: 1.4029 - val_loss: 5.4020 - val_y1_output_loss: 0.5462 - val_y2_output_loss: 4.8256 - val_y1_output_root_mean_squared_error: 0.7419 - val_y2_output_root_mean_squared_error: 2.2026
# Epoch 107/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.2363 - y1_output_loss: 0.7337 - y2_output_loss: 2.4797 - y1_output_root_mean_squared_error: 0.8600 - y2_output_root_mean_squared_error: 1.5801 - val_loss: 3.4245 - val_y1_output_loss: 0.7613 - val_y2_output_loss: 2.7423 - val_y1_output_root_mean_squared_error: 0.8753 - val_y2_output_root_mean_squared_error: 1.6305
# Epoch 108/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.9143 - y1_output_loss: 0.7172 - y2_output_loss: 2.1953 - y1_output_root_mean_squared_error: 0.8418 - y2_output_root_mean_squared_error: 1.4851 - val_loss: 7.1050 - val_y1_output_loss: 2.2075 - val_y2_output_loss: 4.8459 - val_y1_output_root_mean_squared_error: 1.5060 - val_y2_output_root_mean_squared_error: 2.1993
# Epoch 109/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.6241 - y1_output_loss: 0.6315 - y2_output_loss: 1.9721 - y1_output_root_mean_squared_error: 0.7957 - y2_output_root_mean_squared_error: 1.4110 - val_loss: 3.0998 - val_y1_output_loss: 0.7079 - val_y2_output_loss: 2.7190 - val_y1_output_root_mean_squared_error: 0.8454 - val_y2_output_root_mean_squared_error: 1.5444
# Epoch 110/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.0497 - y1_output_loss: 0.6363 - y2_output_loss: 2.3986 - y1_output_root_mean_squared_error: 0.7997 - y2_output_root_mean_squared_error: 1.5525 - val_loss: 4.8806 - val_y1_output_loss: 1.0749 - val_y2_output_loss: 3.8526 - val_y1_output_root_mean_squared_error: 1.0510 - val_y2_output_root_mean_squared_error: 1.9432
# Epoch 111/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.5424 - y1_output_loss: 0.5914 - y2_output_loss: 2.0113 - y1_output_root_mean_squared_error: 0.7609 - y2_output_root_mean_squared_error: 1.4012 - val_loss: 8.6747 - val_y1_output_loss: 3.1152 - val_y2_output_loss: 5.9540 - val_y1_output_root_mean_squared_error: 1.7832 - val_y2_output_root_mean_squared_error: 2.3441
# Epoch 112/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.9983 - y1_output_loss: 0.7066 - y2_output_loss: 2.2766 - y1_output_root_mean_squared_error: 0.8423 - y2_output_root_mean_squared_error: 1.5129 - val_loss: 4.7662 - val_y1_output_loss: 1.2614 - val_y2_output_loss: 3.5979 - val_y1_output_root_mean_squared_error: 1.1327 - val_y2_output_root_mean_squared_error: 1.8663
# Epoch 113/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.5788 - y1_output_loss: 1.4024 - y2_output_loss: 3.2241 - y1_output_root_mean_squared_error: 1.1840 - y2_output_root_mean_squared_error: 1.7824 - val_loss: 2.7373 - val_y1_output_loss: 0.5458 - val_y2_output_loss: 2.3383 - val_y1_output_root_mean_squared_error: 0.7484 - val_y2_output_root_mean_squared_error: 1.4755
# Epoch 114/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.5947 - y1_output_loss: 0.4934 - y2_output_loss: 2.1144 - y1_output_root_mean_squared_error: 0.7039 - y2_output_root_mean_squared_error: 1.4489 - val_loss: 3.1287 - val_y1_output_loss: 0.8217 - val_y2_output_loss: 2.5824 - val_y1_output_root_mean_squared_error: 0.9148 - val_y2_output_root_mean_squared_error: 1.5139
# Epoch 115/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.0112 - y1_output_loss: 0.6073 - y2_output_loss: 2.3877 - y1_output_root_mean_squared_error: 0.7828 - y2_output_root_mean_squared_error: 1.5487 - val_loss: 3.8826 - val_y1_output_loss: 1.2046 - val_y2_output_loss: 2.7755 - val_y1_output_root_mean_squared_error: 1.0974 - val_y2_output_root_mean_squared_error: 1.6366
# Epoch 116/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5652 - y1_output_loss: 0.6747 - y2_output_loss: 1.9077 - y1_output_root_mean_squared_error: 0.8243 - y2_output_root_mean_squared_error: 1.3732 - val_loss: 4.5349 - val_y1_output_loss: 0.6419 - val_y2_output_loss: 4.3912 - val_y1_output_root_mean_squared_error: 0.8124 - val_y2_output_root_mean_squared_error: 1.9685
# Epoch 117/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.3688 - y1_output_loss: 0.5827 - y2_output_loss: 1.8460 - y1_output_root_mean_squared_error: 0.7643 - y2_output_root_mean_squared_error: 1.3359 - val_loss: 4.4041 - val_y1_output_loss: 0.6022 - val_y2_output_loss: 3.7695 - val_y1_output_root_mean_squared_error: 0.7762 - val_y2_output_root_mean_squared_error: 1.9498
# Epoch 118/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.5964 - y1_output_loss: 1.0989 - y2_output_loss: 2.4831 - y1_output_root_mean_squared_error: 1.0498 - y2_output_root_mean_squared_error: 1.5793 - val_loss: 3.9438 - val_y1_output_loss: 0.8802 - val_y2_output_loss: 3.1094 - val_y1_output_root_mean_squared_error: 0.9450 - val_y2_output_root_mean_squared_error: 1.7466
# Epoch 119/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.2011 - y1_output_loss: 0.4636 - y2_output_loss: 1.7364 - y1_output_root_mean_squared_error: 0.6802 - y2_output_root_mean_squared_error: 1.3185 - val_loss: 6.6309 - val_y1_output_loss: 1.3852 - val_y2_output_loss: 5.7049 - val_y1_output_root_mean_squared_error: 1.1855 - val_y2_output_root_mean_squared_error: 2.2859
# Epoch 120/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.4331 - y1_output_loss: 0.5686 - y2_output_loss: 1.8581 - y1_output_root_mean_squared_error: 0.7555 - y2_output_root_mean_squared_error: 1.3647 - val_loss: 2.7664 - val_y1_output_loss: 0.7334 - val_y2_output_loss: 2.1330 - val_y1_output_root_mean_squared_error: 0.8596 - val_y2_output_root_mean_squared_error: 1.4239
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3565 - y1_output_loss: 0.1025 - y2_output_loss: 0.2524 - y1_output_root_mean_squared_error: 0.3213 - y2_output_root_mean_squared_error: 0.5033 - val_loss: 0.8670 - val_y1_output_loss: 0.1635 - val_y2_output_loss: 0.7586 - val_y1_output_root_mean_squared_error: 0.3992 - val_y2_output_root_mean_squared_error: 0.8412
# Epoch 462/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.5263 - y1_output_loss: 0.1404 - y2_output_loss: 0.3955 - y1_output_root_mean_squared_error: 0.3722 - y2_output_root_mean_squared_error: 0.6227 - val_loss: 1.9241 - val_y1_output_loss: 0.3529 - val_y2_output_loss: 1.6759 - val_y1_output_root_mean_squared_error: 0.5913 - val_y2_output_root_mean_squared_error: 1.2548
# Epoch 463/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.4151 - y1_output_loss: 0.1168 - y2_output_loss: 0.2985 - y1_output_root_mean_squared_error: 0.3427 - y2_output_root_mean_squared_error: 0.5455 - val_loss: 0.9827 - val_y1_output_loss: 0.1920 - val_y2_output_loss: 0.8184 - val_y1_output_root_mean_squared_error: 0.4372 - val_y2_output_root_mean_squared_error: 0.8897
# Epoch 464/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5509 - y1_output_loss: 0.1381 - y2_output_loss: 0.4091 - y1_output_root_mean_squared_error: 0.3730 - y2_output_root_mean_squared_error: 0.6417 - val_loss: 1.1243 - val_y1_output_loss: 0.1803 - val_y2_output_loss: 1.0321 - val_y1_output_root_mean_squared_error: 0.4169 - val_y2_output_root_mean_squared_error: 0.9749
# Epoch 465/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3841 - y1_output_loss: 0.1056 - y2_output_loss: 0.2763 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.5272 - val_loss: 0.8325 - val_y1_output_loss: 0.1565 - val_y2_output_loss: 0.7236 - val_y1_output_root_mean_squared_error: 0.3899 - val_y2_output_root_mean_squared_error: 0.8249
# Epoch 466/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4342 - y1_output_loss: 0.1248 - y2_output_loss: 0.3078 - y1_output_root_mean_squared_error: 0.3534 - y2_output_root_mean_squared_error: 0.5561 - val_loss: 0.8311 - val_y1_output_loss: 0.1409 - val_y2_output_loss: 0.7292 - val_y1_output_root_mean_squared_error: 0.3744 - val_y2_output_root_mean_squared_error: 0.8312
# Epoch 467/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4171 - y1_output_loss: 0.1181 - y2_output_loss: 0.2961 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.5464 - val_loss: 1.0148 - val_y1_output_loss: 0.1643 - val_y2_output_loss: 0.9179 - val_y1_output_root_mean_squared_error: 0.4036 - val_y2_output_root_mean_squared_error: 0.9230
# Epoch 468/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3833 - y1_output_loss: 0.1162 - y2_output_loss: 0.2671 - y1_output_root_mean_squared_error: 0.3418 - y2_output_root_mean_squared_error: 0.5162 - val_loss: 0.8830 - val_y1_output_loss: 0.1527 - val_y2_output_loss: 0.7734 - val_y1_output_root_mean_squared_error: 0.3883 - val_y2_output_root_mean_squared_error: 0.8557
# Epoch 469/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4453 - y1_output_loss: 0.1362 - y2_output_loss: 0.3084 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.5566 - val_loss: 0.8036 - val_y1_output_loss: 0.1336 - val_y2_output_loss: 0.7298 - val_y1_output_root_mean_squared_error: 0.3605 - val_y2_output_root_mean_squared_error: 0.8208
# Epoch 470/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4624 - y1_output_loss: 0.1356 - y2_output_loss: 0.3234 - y1_output_root_mean_squared_error: 0.3695 - y2_output_root_mean_squared_error: 0.5708 - val_loss: 0.7672 - val_y1_output_loss: 0.1435 - val_y2_output_loss: 0.6516 - val_y1_output_root_mean_squared_error: 0.3787 - val_y2_output_root_mean_squared_error: 0.7898
# Epoch 471/500
# 614/614 [==============================] - 0s 145us/sample - loss: 1.0018 - y1_output_loss: 0.2103 - y2_output_loss: 0.7919 - y1_output_root_mean_squared_error: 0.4565 - y2_output_root_mean_squared_error: 0.8907 - val_loss: 2.4408 - val_y1_output_loss: 0.5674 - val_y2_output_loss: 2.0110 - val_y1_output_root_mean_squared_error: 0.7379 - val_y2_output_root_mean_squared_error: 1.3770
# Epoch 472/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4151 - y1_output_loss: 0.1141 - y2_output_loss: 0.2987 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.5488 - val_loss: 0.8761 - val_y1_output_loss: 0.1421 - val_y2_output_loss: 0.7771 - val_y1_output_root_mean_squared_error: 0.3754 - val_y2_output_root_mean_squared_error: 0.8574
# Epoch 473/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3934 - y1_output_loss: 0.1018 - y2_output_loss: 0.2904 - y1_output_root_mean_squared_error: 0.3203 - y2_output_root_mean_squared_error: 0.5393 - val_loss: 1.0363 - val_y1_output_loss: 0.1978 - val_y2_output_loss: 0.9018 - val_y1_output_root_mean_squared_error: 0.4437 - val_y2_output_root_mean_squared_error: 0.9162
# Epoch 474/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4665 - y1_output_loss: 0.1315 - y2_output_loss: 0.3322 - y1_output_root_mean_squared_error: 0.3639 - y2_output_root_mean_squared_error: 0.5780 - val_loss: 0.7578 - val_y1_output_loss: 0.1344 - val_y2_output_loss: 0.6663 - val_y1_output_root_mean_squared_error: 0.3607 - val_y2_output_root_mean_squared_error: 0.7923
# Epoch 475/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4120 - y1_output_loss: 0.1159 - y2_output_loss: 0.3015 - y1_output_root_mean_squared_error: 0.3413 - y2_output_root_mean_squared_error: 0.5436 - val_loss: 3.4743 - val_y1_output_loss: 0.3956 - val_y2_output_loss: 3.2522 - val_y1_output_root_mean_squared_error: 0.6210 - val_y2_output_root_mean_squared_error: 1.7574
# Epoch 476/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4522 - y1_output_loss: 0.1320 - y2_output_loss: 0.3186 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.5657 - val_loss: 0.8610 - val_y1_output_loss: 0.1677 - val_y2_output_loss: 0.7412 - val_y1_output_root_mean_squared_error: 0.4059 - val_y2_output_root_mean_squared_error: 0.8344
# Epoch 477/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.5787 - y1_output_loss: 0.1405 - y2_output_loss: 0.4370 - y1_output_root_mean_squared_error: 0.3757 - y2_output_root_mean_squared_error: 0.6615 - val_loss: 1.5650 - val_y1_output_loss: 0.2761 - val_y2_output_loss: 1.4302 - val_y1_output_root_mean_squared_error: 0.5073 - val_y2_output_root_mean_squared_error: 1.1436
# Epoch 478/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4239 - y1_output_loss: 0.1233 - y2_output_loss: 0.2971 - y1_output_root_mean_squared_error: 0.3520 - y2_output_root_mean_squared_error: 0.5477 - val_loss: 1.0358 - val_y1_output_loss: 0.1526 - val_y2_output_loss: 0.9593 - val_y1_output_root_mean_squared_error: 0.3837 - val_y2_output_root_mean_squared_error: 0.9426
# Epoch 479/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4647 - y1_output_loss: 0.1357 - y2_output_loss: 0.3262 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.5726 - val_loss: 0.8807 - val_y1_output_loss: 0.1876 - val_y2_output_loss: 0.7446 - val_y1_output_root_mean_squared_error: 0.4283 - val_y2_output_root_mean_squared_error: 0.8350
# Epoch 480/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.5065 - y1_output_loss: 0.1182 - y2_output_loss: 0.3858 - y1_output_root_mean_squared_error: 0.3444 - y2_output_root_mean_squared_error: 0.6228 - val_loss: 1.5534 - val_y1_output_loss: 0.3051 - val_y2_output_loss: 1.3396 - val_y1_output_root_mean_squared_error: 0.5442 - val_y2_output_root_mean_squared_error: 1.1213
# Epoch 481/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3832 - y1_output_loss: 0.1220 - y2_output_loss: 0.2664 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.5143 - val_loss: 2.3183 - val_y1_output_loss: 0.4748 - val_y2_output_loss: 1.9374 - val_y1_output_root_mean_squared_error: 0.6881 - val_y2_output_root_mean_squared_error: 1.3582
# Epoch 482/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.7639 - y1_output_loss: 0.2255 - y2_output_loss: 0.5342 - y1_output_root_mean_squared_error: 0.4770 - y2_output_root_mean_squared_error: 0.7324 - val_loss: 1.1761 - val_y1_output_loss: 0.1666 - val_y2_output_loss: 1.1188 - val_y1_output_root_mean_squared_error: 0.4007 - val_y2_output_root_mean_squared_error: 1.0077
# Epoch 483/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3869 - y1_output_loss: 0.1112 - y2_output_loss: 0.2766 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.5250 - val_loss: 0.7813 - val_y1_output_loss: 0.1433 - val_y2_output_loss: 0.6867 - val_y1_output_root_mean_squared_error: 0.3743 - val_y2_output_root_mean_squared_error: 0.8007
# Epoch 484/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.4406 - y1_output_loss: 0.1227 - y2_output_loss: 0.3145 - y1_output_root_mean_squared_error: 0.3510 - y2_output_root_mean_squared_error: 0.5634 - val_loss: 0.8986 - val_y1_output_loss: 0.1466 - val_y2_output_loss: 0.8093 - val_y1_output_root_mean_squared_error: 0.3787 - val_y2_output_root_mean_squared_error: 0.8690
# Epoch 485/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4552 - y1_output_loss: 0.1194 - y2_output_loss: 0.3339 - y1_output_root_mean_squared_error: 0.3458 - y2_output_root_mean_squared_error: 0.5793 - val_loss: 1.0628 - val_y1_output_loss: 0.1567 - val_y2_output_loss: 0.9819 - val_y1_output_root_mean_squared_error: 0.3875 - val_y2_output_root_mean_squared_error: 0.9553
# Epoch 486/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3515 - y1_output_loss: 0.1171 - y2_output_loss: 0.2364 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.4845 - val_loss: 1.2975 - val_y1_output_loss: 0.2726 - val_y2_output_loss: 1.1361 - val_y1_output_root_mean_squared_error: 0.5110 - val_y2_output_root_mean_squared_error: 1.0181
# Epoch 487/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4484 - y1_output_loss: 0.1330 - y2_output_loss: 0.3115 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.5605 - val_loss: 0.8575 - val_y1_output_loss: 0.1737 - val_y2_output_loss: 0.7187 - val_y1_output_root_mean_squared_error: 0.4153 - val_y2_output_root_mean_squared_error: 0.8277
# Epoch 488/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.5813 - y1_output_loss: 0.1453 - y2_output_loss: 0.4327 - y1_output_root_mean_squared_error: 0.3818 - y2_output_root_mean_squared_error: 0.6599 - val_loss: 0.8212 - val_y1_output_loss: 0.1569 - val_y2_output_loss: 0.7448 - val_y1_output_root_mean_squared_error: 0.3879 - val_y2_output_root_mean_squared_error: 0.8190
# Epoch 489/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3297 - y1_output_loss: 0.1056 - y2_output_loss: 0.2248 - y1_output_root_mean_squared_error: 0.3263 - y2_output_root_mean_squared_error: 0.4724 - val_loss: 0.8619 - val_y1_output_loss: 0.1510 - val_y2_output_loss: 0.7539 - val_y1_output_root_mean_squared_error: 0.3858 - val_y2_output_root_mean_squared_error: 0.8444
# Epoch 490/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.5103 - y1_output_loss: 0.1273 - y2_output_loss: 0.3817 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.6181 - val_loss: 0.8659 - val_y1_output_loss: 0.1812 - val_y2_output_loss: 0.7325 - val_y1_output_root_mean_squared_error: 0.4203 - val_y2_output_root_mean_squared_error: 0.8302
# Epoch 491/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3870 - y1_output_loss: 0.1169 - y2_output_loss: 0.2676 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.5195 - val_loss: 0.8779 - val_y1_output_loss: 0.2099 - val_y2_output_loss: 0.7216 - val_y1_output_root_mean_squared_error: 0.4534 - val_y2_output_root_mean_squared_error: 0.8200
# Epoch 492/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.5829 - y1_output_loss: 0.1508 - y2_output_loss: 0.4287 - y1_output_root_mean_squared_error: 0.3901 - y2_output_root_mean_squared_error: 0.6563 - val_loss: 0.8276 - val_y1_output_loss: 0.1692 - val_y2_output_loss: 0.6989 - val_y1_output_root_mean_squared_error: 0.4099 - val_y2_output_root_mean_squared_error: 0.8121
# Epoch 493/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.3257 - y1_output_loss: 0.1088 - y2_output_loss: 0.2184 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.4653 - val_loss: 0.8862 - val_y1_output_loss: 0.1473 - val_y2_output_loss: 0.7820 - val_y1_output_root_mean_squared_error: 0.3794 - val_y2_output_root_mean_squared_error: 0.8615
# Epoch 494/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4065 - y1_output_loss: 0.1106 - y2_output_loss: 0.2939 - y1_output_root_mean_squared_error: 0.3322 - y2_output_root_mean_squared_error: 0.5442 - val_loss: 0.8612 - val_y1_output_loss: 0.1584 - val_y2_output_loss: 0.7512 - val_y1_output_root_mean_squared_error: 0.3946 - val_y2_output_root_mean_squared_error: 0.8400
# Epoch 495/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3539 - y1_output_loss: 0.1073 - y2_output_loss: 0.2456 - y1_output_root_mean_squared_error: 0.3270 - y2_output_root_mean_squared_error: 0.4970 - val_loss: 1.2590 - val_y1_output_loss: 0.2611 - val_y2_output_loss: 1.0439 - val_y1_output_root_mean_squared_error: 0.5073 - val_y2_output_root_mean_squared_error: 1.0008
# Epoch 496/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4732 - y1_output_loss: 0.1358 - y2_output_loss: 0.3428 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.5837 - val_loss: 1.1549 - val_y1_output_loss: 0.2302 - val_y2_output_loss: 0.9337 - val_y1_output_root_mean_squared_error: 0.4854 - val_y2_output_root_mean_squared_error: 0.9588
# Epoch 497/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.4734 - y1_output_loss: 0.1346 - y2_output_loss: 0.3369 - y1_output_root_mean_squared_error: 0.3666 - y2_output_root_mean_squared_error: 0.5823 - val_loss: 0.9982 - val_y1_output_loss: 0.2086 - val_y2_output_loss: 0.8524 - val_y1_output_root_mean_squared_error: 0.4473 - val_y2_output_root_mean_squared_error: 0.8934
# Epoch 498/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3898 - y1_output_loss: 0.1117 - y2_output_loss: 0.2767 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5270 - val_loss: 0.9879 - val_y1_output_loss: 0.1580 - val_y2_output_loss: 0.9183 - val_y1_output_root_mean_squared_error: 0.3867 - val_y2_output_root_mean_squared_error: 0.9156
# Epoch 499/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.5007 - y1_output_loss: 0.1531 - y2_output_loss: 0.3439 - y1_output_root_mean_squared_error: 0.3927 - y2_output_root_mean_squared_error: 0.5887 - val_loss: 0.8113 - val_y1_output_loss: 0.1800 - val_y2_output_loss: 0.6735 - val_y1_output_root_mean_squared_error: 0.4220 - val_y2_output_root_mean_squared_error: 0.7957
# Epoch 500/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.3405 - y1_output_loss: 0.1138 - y2_output_loss: 0.2258 - y1_output_root_mean_squared_error: 0.3362 - y2_output_root_mean_squared_error: 0.4769 - val_loss: 0.8042 - val_y1_output_loss: 0.1697 - val_y2_output_loss: 0.6859 - val_y1_output_root_mean_squared_error: 0.4139 - val_y2_output_root_mean_squared_error: 0.7955

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.8042 - y1_output_loss: 0.1695 - y2_output_loss: 0.6441 - y1_output_root_mean_squared_error: 0.4139 - y2_output_root_mean_squared_error: 0.7955
# Loss = 0.8042203079570424, Y1_loss = 0.16953885555267334, Y1_mse = 0.4139195382595062, Y2_loss = 0.6440690159797668, Y2_mse = 0.795544445514679

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
